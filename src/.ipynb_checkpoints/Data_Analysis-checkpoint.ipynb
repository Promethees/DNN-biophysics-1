# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/vacuum_data.csv')
plt.figure(figsize=(8, 6))
sns.scatterplot(x='sin_theta_1', y='sin_theta_2', hue='p_B', size='p_B', data=df)
plt.title('Dummy Committor Distribution (Vacuum)')
# Out:
# Text(0.5, 1.0, 'Dummy Committor Distribution (Vacuum)')
